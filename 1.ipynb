# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.0
# 1.26.4

# %%
n_baris = 10
n_kolom = 5
header = tuple("ABCDE")

df = pd.DataFrame(np.random.randint(1, 10, size=(n_baris, n_kolom)), columns=header)

df.add_prefix('kolom_')
# df.add_suffix('_field')
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        7        1        6        6        7
# 1        1        8        6        2        6
# 2        4        7        4        9        2
# 3        4        7        6        9        7
# 4        4        8        4        9        7
# 5        1        8        2        9        9
# 6        2        4        1        8        7
# 7        6        3        2        7        1
# 8        3        8        2        1        5
# 9        7        7        2        8        7

# %%
df[df['A'].isin([1, 3, 5, 7, 9])]
# Out:
#    A  B  C  D  E
# 0  7  1  6  6  7
# 1  1  8  6  2  6
# 5  1  8  2  9  9
# 8  3  8  2  1  5
# 9  7  7  2  8  7

# %%
df[(df['A'] == 1) | (df['A'] == 3)]
# Out:
#    A  B  C  D  E
# 1  1  8  6  2  6
# 5  1  8  2  9  9
# 8  3  8  2  1  5

# %%
# untuk kondisi tidak sama dengan (not) menggunakan tanda ~(negasi)

df[~df['A'].isin([1, 3, 5, 7, 9])]
# Out:
#    A  B  C  D  E
# 2  4  7  4  9  2
# 3  4  7  6  9  7
# 4  4  8  4  9  7
# 6  2  4  1  8  7
# 7  6  3  2  7  1
