# %%
import pandas as pd

df = pd.read_csv('datatraining.txt', delimiter=',')
df.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
df.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  8143.000000  8143.000000  8143.000000  8143.000000    8143.000000
# mean     20.619084    25.731507   119.519375   606.546243       0.003863
# std       1.016916     5.531211   194.755805   314.320877       0.000852
# min      19.000000    16.745000     0.000000   412.750000       0.002674
# 25%      19.700000    20.200000     0.000000   439.000000       0.003078
# 50%      20.390000    26.222500     0.000000   453.500000       0.003801
# 75%      21.390000    30.533333   256.375000   638.833333       0.004352
# max      23.180000    39.117500  1546.333333  2028.500000       0.006476
#
#          Occupancy
# count  8143.000000
# mean      0.212330
# std       0.408982
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.groupby('Occupancy').count()
# Out:
#            date  Temperature  Humidity  Light   CO2  HumidityRatio
# Occupancy
# 0          6414         6414      6414   6414  6414           6414
# 1          1729         1729      1729   1729  1729           1729

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date             datetime64[ns]
# Temperature             float64
# Humidity                float64
# Light                   float64
# CO2                     float64
# HumidityRatio           float64
# Occupancy                 int64
# dtype: object

# %%
df.resample('D', on='date').mean()
# Out:
#             Temperature   Humidity       Light         CO2  HumidityRatio  \
# date
# 2015-02-04    21.765255  26.413291   18.271003  535.448284       0.004262
# 2015-02-05    21.469044  24.189298  196.227928  685.939508       0.003841
# 2015-02-06    20.880500  19.838108  199.104201  597.644051       0.003029
# 2015-02-07    20.576546  20.639422   66.854352  443.590000       0.003074
# 2015-02-08    19.510642  29.200364   25.012199  433.987454       0.004091
# 2015-02-09    20.498565  31.659897  167.386111  943.754277       0.004769
# 2015-02-10    20.283957  33.146608   41.641405  471.163110       0.004882
#
#             Occupancy
# date
# 2015-02-04   0.043360
# 2015-02-05   0.374306
# 2015-02-06   0.406944
# 2015-02-07   0.000000
# 2015-02-08   0.000000
# 2015-02-09   0.370833
# 2015-02-10   0.094077

# %%
import matplotlib.pyplot as plt
figure, axis = plt.subplots(5, figsize=(10, 6))
axis[0].plot(df['Temperature'])
axis[0].set_title('Temperature')
axis[1].plot(df['Humidity'])
axis[1].set_title('Humidity')
axis[2].plot(df['Light'])
axis[2].set_title('Light')
axis[3].plot(df['CO2'])
axis[3].set_title('CO2')
axis[4].plot(df['Occupancy'])
axis[4].set_title('Occupancy')
figure.tight_layout()
