# %%
import pandas as pd  

df_churning = pd.read_csv('BankChurners.csv')

df_churning.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
df_churning.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# ...

# %%
existing_data = df_churning[df_churning['Attrition_Flag'] == 'Existing Customer']
attriting_data = df_churning[df_churning['Attrition_Flag'] == 'Attrited Customer']

# %%
# line chart
import matplotlib.pyplot as plt
import numpy as np

x = np.array([2,4,6,8])

y1 = np.array([3, 8, 1, 10])
y2 = np.array([4, 7, 10, 12])

plt.plot(x, y1, marker = 'o')
plt.plot(x, y2, marker = 'x')

plt.show()

# %%
import pandas as pd

df_iot = pd.read_csv('datatraining.txt', delimiter=',')
df_iot['date'] = pd.to_datetime(df_iot['date'])

df_iot.head()
# Out:
#                  date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1 2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2 2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3 2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4 2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5 2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
plt.figure(figsize=(15, 3))
plt.plot(df_iot['date'], df_iot['Humidity'])
plt.show()

# %%
# pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Web Programmer", "Data Scientist", "Data Analyst", "Software Engineer"]

plt.pie(y, labels = mylabels, autopct='%.2f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
# melihat jumlah data pada kolom 'Marital_Status' dan menghitung jumlah data yang berbeda
df = df_churning['Marital_Status'].value_counts()
# index semua label data yang berbeda
label = df.index
# membuat pie chart
plt.pie(df, labels = label, autopct='%.2f%%')
plt.title('Marital Status')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 

y = np.array([35, 25, 25, 15])
x = ["Web Programmer", "Data Scientist", "DB Admin", "Manager"]

plt.bar(x, y)
# rotasi label
plt.xticks(rotation=45)
plt.ylabel('Jumlah')
plt.show()

# %%
y1 = existing_data['Marital_Status'].value_counts()
y2 = attriting_data['Marital_Status'].value_counts()

x1 = np.arange(len(y1.index))
x2 = np.arange(len(y2.index))

bar_width = 0.4

plt.bar(x1, y1, bar_width, label='Existing Customer')
plt.bar(x2+bar_width, y2, bar_width, label='Attrited Customer')

plt.title('Marital Status')
plt.ylabel('Jumlah')
plt.xticks(x2 + bar_width/2, labels=df_churning.Marital_Status.unique())

plt.show()

# %%
# versi 2 lebih mudah pakai fungsi plot.bar
data1 = existing_data['Marital_Status'].value_counts()
data2 = attriting_data['Marital_Status'].value_counts()

df_new = pd.concat([data1, data2], keys=['existing', 'attrited'], axis=1)
df_new.plot(kind='bar')

plt.title('Marital Status')
plt.ylabel('Jumlah')
plt.show()

# %%
df_new
# Out:
#                 existing  attrited
# Marital_Status
# Married             3978       709
# Single              3275       668
# Divorced             627       121
# Unknown              620       129

# %%
# stacked bar plot
data1 = existing_data['Marital_Status'].value_counts()
data2 = attriting_data['Marital_Status'].value_counts()
df_new = pd.concat([data1, data2], keys=['existing', 'attrited'], axis=1)

df_new.plot(kind='bar', stacked=True)
plt.title('Marital Status')
plt.ylabel('Jumlah')
plt.show()

# %%
# membuat dataframe baru, yang menjelaskan presentase dari setiap status pernikahan
df_new['existing_percentage'] = df_new['existing'] / (df_new['existing'] + df_new['attrited']) * 100
df_new['attrited_percentage'] = df_new['attrited'] / (df_new['existing'] + df_new['attrited']) * 100
df_new
# Out:
#                 existing  attrited  existing_percentage  attrited_percentage
# Marital_Status
# Married             3978       709            84.873053            15.126947
# Single              3275       668            83.058585            16.941415
# Divorced             627       121            83.823529            16.176471
# Unknown              620       129            82.777036            17.222964

# %%
# histogram
data = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
nilai = [0,25,50,75,100]
plt.hist(data, bins = nilai)
plt.title("histogram")
plt.xticks([0,25,50,75,100])
plt.xlabel('nilai')
plt.ylabel('jumlah siswa')
plt.show()

# %%
data1 = existing_data['Customer_Age']
data2 = attriting_data['Customer_Age']

plt.hist(data1, label="existing")
plt.hist(data2, label="attrited")

plt.title('Customer age')
plt.ylabel('Jumlah')
plt.xlabel('Umur')

plt.legend()
plt.show()

# %%
# scatter plot
w_a = np.array([50, 65, 75, 55])
h_a = np.array([155, 165, 180, 160])

w_b = np.array([60, 75, 65, 70])
h_b = np.array([160, 175, 170, 173])

plt.scatter(w_a, h_a)
plt.scatter(w_b, h_b)

plt.title('Berat vs Tinggi Badan')
plt.ylabel('Tinggi Badan(cm)')
plt.xlabel('Berat Badan(kg)')
plt.show()

# %%
# pakai dataset
y1 = attriting_data['Months_on_book']
x1 = attriting_data['Customer_Age']

y2 = existing_data['Months_on_book']
x2 = existing_data['Customer_Age']

plt.scatter(x2,y2, label='Existing Customer')
plt.scatter(x1,y1, label='Attrited Customer')

plt.title('Customer age vs months on book')
plt.ylabel('Months on Book')
plt.xlabel('Customer Age')
plt.legend()

plt.show()

# %%
# versi 2 pakai fungsi plot.scatter dari object dataframe
ax = existing_data.plot.scatter(x='Customer_Age', y='Months_on_book', color='Blue', label='Existing Customer')
attriting_data.plot.scatter(x='Customer_Age', y='Months_on_book', color='Red', label='Attrited Customer', ax=ax)

plt.title('Customer age vs months on book')
plt.ylabel('Months on Book')
plt.xlabel('Customer Age')
plt.show()

# %%
# boxplot
plt.boxplot(df_churning['Customer_Age'])
plt.title('Customer Age')
plt.ylabel('age')
plt.xticks([1], labels=['all customers'])
plt.show()

# %%
data = np.random.normal(70, 10, 200) #buat data random, rata2 70, std dev 10, jumlah data 200
plt.boxplot(data)
plt.xticks([1], labels=['Umur'])
plt.show()

# %%
data1 = existing_data['Customer_Age'].values
data2 = attriting_data['Customer_Age'].values
# make dict object
mydict = {'existing': data1, 'attrited': data2}
# ambil value dict
plt.boxplot(list(mydict.values()))
plt.title('customer age')
plt.ylabel('age')
plt.xticks([1,2], labels=list(mydict.keys()))
plt.show()

# %%
# veris 2 pake fungsi plot.box
data1 = existing_data['Customer_Age']
data2 = attriting_data['Customer_Age']
df_new = pd.concat([data1, data2], keys=['existing', 'attrited'], axis=1)
df_new.plot.box()

plt.title('Customer Age')
plt.ylabel('age')
plt.show()

# %% [markdown]
# # violin plot
# Violin plot adalah jenis grafik yang menampilkan distribusi data numerik dengan menggunakan bentuk mirip biola yang menunjukkan kerapatan relatif dari nilai data di berbagai bagian rentang nilai,
# memungkinkan untuk melihat bentuk distribusi data secara lebih rinci daripada histogram dan box plot.

# %%
np.random.seed(10)
data = np.random.normal(70, 10, 200)
plt.violinplot(data)

plt.xticks([1], labels=['Umur'])
plt.show()

# %%
#pakai dataset churn
data1 = existing_data['Customer_Age'].values
data2 = attriting_data['Customer_Age'].values
mydict = {'existing': data1, 'attrited': data2}

plt.violinplot(list(mydict.values()))

plt.xticks([1,2], labels=list(mydict.keys()))
plt.show()
